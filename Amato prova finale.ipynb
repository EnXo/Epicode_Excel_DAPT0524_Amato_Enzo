# %%
import pandas as pd

# Link raw del file CSV e percorso locale - decommentare quello da usare!
# path = "https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv"
path = "C:/Users/info/Documents/Data/Corso Epicode/Modulo 4 Python/Prova finale Python/owid-covid-data.csv"

covid = pd.read_csv(path)

# Modifica l'impostazione per mostrare tutte le colonne e righe
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
type(covid)
# Out:
# pandas.core.frame.DataFrame

# %%
covid.shape
# Out:
# (429435, 67)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 429435 entries, 0 to 429434
# Data columns (total 67 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    429435 non-null  object
#  1   continent                                   402910 non-null  object
#  2   location                                    429435 non-null  object
#  3   date                                        429435 non-null  object
#  4   total_cases                                 411804 non-null  float64
#  5   new_cases                                   410159 non-null  float64
#  6   new_cases_smoothed                          408929 non-null  float64
#  7   total_deaths                                411804 non-null  float64
#  8   new_deaths                                  410608 non-null  float64
# ...

# %%
covid.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-05          0.0        0.0
# 1      AFG      Asia  Afghanistan  2020-01-06          0.0        0.0
# 2      AFG      Asia  Afghanistan  2020-01-07          0.0        0.0
# 3      AFG      Asia  Afghanistan  2020-01-08          0.0        0.0
# 4      AFG      Asia  Afghanistan  2020-01-09          0.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           0.0         0.0                  NaN  ...
# 1                 NaN           0.0         0.0                  NaN  ...
# 2                 NaN           0.0         0.0                  NaN  ...
# 3                 NaN           0.0         0.0                  NaN  ...
# 4                 NaN           0.0         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
covid.tail(2)
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 429433      ZWE    Africa  Zimbabwe  2024-08-03     266386.0        0.0
# 429434      ZWE    Africa  Zimbabwe  2024-08-04     266386.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 429433                 0.0        5740.0         0.0                  0.0
# 429434                 0.0        5740.0         0.0                  0.0
#
#         ...  male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 429433  ...          30.7                   36.79                         1.7
# 429434  ...          30.7                   36.79                         1.7
#
#         life_expectancy  human_development_index  population  \
# 429433            61.49                     0.57    16320539
# 429434            61.49                     0.57    16320539
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# ...

# %%
# Configurazione per vedere tutte le colonne
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Mostrare il numero di valori univoci in ogni colonna
print(covid.nunique())
# Out:
# iso_code                                        255
# continent                                         6
# location                                        255
# date                                           1688
# total_cases                                   36694
# new_cases                                     14158
# new_cases_smoothed                            14158
# total_deaths                                  16763
# new_deaths                                     3500
# new_deaths_smoothed                            3500
# total_cases_per_million                       41115
# new_cases_per_million                         25319
# new_cases_smoothed_per_million                16702
# total_deaths_per_million                      23992
# new_deaths_per_million                         4508
# new_deaths_smoothed_per_million                1485
# reproduction_rate                               380
# icu_patients                                   4133
# ...

# %%
covid['location'].value_counts()
# Out:
# location
# High-income countries               3026
# European Union (27)                 3024
# Upper-middle-income countries       3013
# Lower-middle-income countries       2983
# Low-income countries                2724
# East Timor                          2688
# Faroe Islands                       2068
# Asia                                1684
# Malaysia                            1684
# Europe                              1684
# Lithuania                           1684
# World                               1684
# India                               1682
# Estonia                             1682
# Czechia                             1682
# Oceania                             1681
# New Zealand                         1681
# Mexico                              1678
# Argentina                           1678
# Italy                               1677
# Thailand                            1675
# Puerto Rico                         1674
# Niger                               1674
# ...

# %%
covid['location'].value_counts()
covid['continent'].value_counts()
# Out:
# continent
# Africa           95419
# Europe           91031
# Asia             84199
# North America    68638
# Oceania          40183
# South America    23440
# Name: count, dtype: int64

# %%
covid['tests_units'].unique()
# Out:
# array([nan, 'tests performed', 'units unclear', 'samples tested',
#        'people tested'], dtype=object)

# %%
covid.sample(5)
# Out:
#        iso_code      continent             location        date  total_cases  \
# 145021      GIB         Europe            Gibraltar  2023-06-20      20550.0
# 14829       ATG  North America  Antigua and Barbuda  2023-12-12       9106.0
# 404394      USA  North America        United States  2022-08-05   90232883.0
# 237414      MTQ  North America           Martinique  2021-02-24       6593.0
# 340951      SRB         Europe               Serbia  2020-05-11      10032.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 145021        0.0                0.00         113.0         0.0
# 14829         0.0                0.00         146.0         0.0
# 404394        0.0           135426.14     1021593.0         0.0
# 237414        0.0                0.00          45.0         0.0
# 340951        0.0               95.71         213.0         0.0
#
#         new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# ...

# %%
covid.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  total_deaths  \
# count  4.118040e+05  4.101590e+05        4.089290e+05  4.118040e+05
# mean   7.365292e+06  8.017360e+03        8.041026e+03  8.125957e+04
# std    4.477582e+07  2.296649e+05        8.661611e+04  4.411901e+05
# min    0.000000e+00  0.000000e+00        0.000000e+00  0.000000e+00
# 25%    6.280750e+03  0.000000e+00        0.000000e+00  4.300000e+01
# 50%    6.365300e+04  0.000000e+00        1.200000e+01  7.990000e+02
# 75%    7.582720e+05  0.000000e+00        3.132900e+02  9.574000e+03
# max    7.758668e+08  4.423623e+07        6.319461e+06  7.057132e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  410608.000000        409378.000000            411804.000000
# mean       71.852139            72.060828            112096.199420
# std      1368.322990           513.636565            162240.412405
# min         0.000000             0.000000                 0.000000
# ...

# %%
covid['continent'].unique()
# Out:
# array(['Asia', nan, 'Europe', 'Africa', 'Oceania', 'North America',
#        'South America'], dtype=object)

# %%
covid['continent'].value_counts()
# Out:
# continent
# Africa           95419
# Europe           91031
# Asia             84199
# North America    68638
# Oceania          40183
# South America    23440
# Name: count, dtype: int64

# %%
(covid["location"] == "Italy").sum()
# Out:
# 1677

# %%
covid["location"].nunique()
# Out:
# 255

# %%
f_italy = covid["location"] == "Italy"
f_italy22 = covid["date"] == "2022"

# %%
italy22 = covid.loc[f_italy22, "date":"new_cases_smoothed"]
print(italy22)
# Out:
# Empty DataFrame
# Columns: [date, total_cases, new_cases, new_cases_smoothed]
# Index: []

# %%
italy = covid.loc[f_italy, "date":"new_cases_smoothed"]

# %% [markdown]
# ## 1. Si richiede di verificare le dimensioni del dataset e i relativi metadati
# Il dataset completo COVID-19 di "Our World in Data" è formato da 67 colonne e da quasi 430 mila righe.
# I primi dati partono dal 5 gennaio 2020 al 4 agosto 2024. Include 255 località divise tra stati ed aree geografiche.
# Le colonne riguardano diversi argomenti, a partire dai dati sulla contaminazione (contagi, ospedalizzazioni, decessi, vaccinazioni), alle politiche di restrizione ed diversi indici demografici e sociali.

# %%
# Conversione della date in datatime
covid["date"] = pd.to_datetime(covid["date"])

print(covid.dtypes)
# Out:
# iso_code                                              object
# continent                                             object
# location                                              object
# date                                          datetime64[ns]
# total_cases                                          float64
# new_cases                                            float64
# new_cases_smoothed                                   float64
# total_deaths                                         float64
# new_deaths                                           float64
# new_deaths_smoothed                                  float64
# total_cases_per_million                              float64
# new_cases_per_million                                float64
# new_cases_smoothed_per_million                       float64
# total_deaths_per_million                             float64
# new_deaths_per_million                               float64
# ...

# %%
col_utili_2 = ["date", "continent", "location", "total_cases", "total_cases_per_million"]
filtro_data_max = covid["date"] == covid["date"].max()

# %%
ultime_date = covid.loc[filtro_data_max, col_utili_2]

# %%
ultime_date.shape
# Out:
# (8, 5)

# %%
ultime_date
# Out:
#              date continent                       location  total_cases  \
# 21775  2024-08-14       NaN                           Asia          NaN
# 120252 2024-08-14       NaN                         Europe          NaN
# 121602 2024-08-14       NaN            European Union (27)          NaN
# 165198 2024-08-14       NaN          High-income countries          NaN
# 217093 2024-08-14    Europe                      Lithuania          NaN
# 230301 2024-08-14      Asia                       Malaysia          NaN
# 408137 2024-08-14       NaN  Upper-middle-income countries          NaN
# 424412 2024-08-14       NaN                          World          NaN
#
#         total_cases_per_million
# 21775                       NaN
# 120252                      NaN
# 121602                      NaN
# 165198                      NaN
# 217093                      NaN
# 230301                      NaN
# 408137                      NaN
# 424412                      NaN

# %%
covid.loc[covid.groupby("continent")["total_cases"].idxmax(), col_utili_2]
# Out:
#              date      continent       location  total_cases  \
# 357556 2024-07-28         Africa   South Africa    4072765.0
# 75343  2024-08-04           Asia          China   99373219.0
# 131634 2023-06-25         Europe         France   38997490.0
# 404676 2023-05-14  North America  United States  103436829.0
# 23372  2024-05-19        Oceania      Australia   11861161.0
# 51459  2023-05-14  South America         Brazil   37511921.0
#
#         total_cases_per_million
# 357556                 65291.25
# 75343                  69726.80
# 131634                606706.00
# 404676                302859.50
# 23372                 452699.00
# 51459                 178367.94

# %%
f_1 = covid["location"] == "Asia"
f_2 = covid["location"] == "Africa"
f_3 = covid["location"] == "Europe"
f_4 = covid["location"] == "North America"
f_5 = covid["location"] == "Oceania"
f_6 = covid["location"] == "South America"
f_continenti = f_1 + f_2 + f_3 + f_4 + f_5 + f_6

# %%
continenti = covid.loc[f_continenti, col_utili_2]

# %%
max = continenti.groupby("location", as_index=False).agg({"total_cases": "max"})

# %%
total_cases_sum = max["total_cases"].sum()

# %%
max.loc[len(max)] = ["World", total_cases_sum]

# %%
max
# Out:
#         location  total_cases
# 0         Africa   13145380.0
# 1           Asia  301499099.0
# 2         Europe  252916868.0
# 3  North America  124492666.0
# 4        Oceania   15003352.0
# 5  South America   68809418.0
# 6          World  775866783.0

# %%
max["percentage"] = (max["total_cases"] / total_cases_sum) * 100

# %% [markdown]
# ## 2. Si chiede di trovare, per ogni continente:
# **a.** il numero di casi fin dall'inizio della pandemia <br>
# **b.** la percentuale rispetto al totale mondiale del numero di casi

# %%
max
# Out:
#         location  total_cases  percentage
# 0         Africa   13145380.0    1.694283
# 1           Asia  301499099.0   38.859648
# 2         Europe  252916868.0   32.597976
# 3  North America  124492666.0   16.045624
# 4        Oceania   15003352.0    1.933754
# 5  South America   68809418.0    8.868716
# 6          World  775866783.0  100.000000

# %%
f_italy = covid["location"] == "Italy"
f_2022 = covid["date"].dt.year == 2022
f_zero = covid["new_cases"] != 0
f_3_a = f_italy & f_2022 
f_3_b = f_italy & f_2022 & f_zero
col_utili_3_a = ["date", "total_cases"]
col_utili_3_b = ["date", "new_cases"]

# %%
ita22_a = covid.loc[f_3_a, col_utili_3_a]
ita22_a = ita22_a.set_index("date")
ita22_b = covid.loc[f_3_b, col_utili_3_b]
ita22_b = ita22_b.set_index("date")

# %%
# ita22_a
# ita22_b

# %%
print(len(ita22_a))
print(len(ita22_b))
# Out:
# 365
# 52

# %%
import matplotlib.pyplot as plt

# %%
print(ita22_a.columns)
print(ita22_b.columns)
# Out:
# Index(['total_cases'], dtype='object')
# Index(['new_cases'], dtype='object')

# %% [markdown]
# ## 3. Selezionare i dati relativi all'Italia nel 2022 e mostrare con dei grafici adeguati:
# **a.** l'evoluzione del casi totali dall'inizio alla fine dell'anno <br>

# %%
plot = ita22_a.plot(legend=False)

plot.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))

plot.set_xlabel("Data")  # Etichetta per l'asse x
plot.set_ylabel("Nuovi casi")  # Etichetta per l'asse y

plt.show()

# %% [markdown]
# ## 3. Selezionare i dati relativi all'Italia nel 2022 e mostrare con dei grafici adeguati:
# **b.** il numero di nuovi casi rispetto alla data <br>
# ------ *k.* poiché i nuovi casi vengono registrati settimanalmente, filtrare via i dati che non hanno misurazioni

# %%
plot = ita22_b.plot(legend=False)

plot.yaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:,.0f}'))

plot.set_xlabel("Data")  # Etichetta per l'asse x
plot.set_ylabel("Nuovi casi")  # Etichetta per l'asse y

plt.show()

# %%
f_ita = covid["location"] == "Italy"
f_ger = covid["location"] == "Germany"
f_fra = covid["location"] == "France"
inizio = "2022-05-01"
fine = "2023-04-30"
f_22_23 = (covid["date"] >= inizio) & (covid["date"] <= fine)
f_4 = (f_ita | f_ger | f_fra)  & f_22_23
col_utili_4 = ["date", "location", "icu_patients"]

# %%
igf = covid.loc[f_4, col_utili_4]

# %%
import seaborn as sns

# %% [markdown]
# ## 4. Riguardo le nazioni di Italia, Germania e Francia mostrare in un boxplot la differenza tra queste nazioni riguardo il numero di pazienti in terapia intensiva (Intensive Care Unit, ICU) da maggio 2022 (incluso) ad aprile 2023 (incluso)
# **a.** scrivere un breve commento a riguardo

# %%
sns.boxplot(data=igf, x="location", y="icu_patients")
# Out:
# <Axes: xlabel='location', ylabel='icu_patients'>

# %%
f_ita = covid["location"] == "Italy"
f_ger = covid["location"] == "Germany"
f_fra = covid["location"] == "France"
f_spa = covid["location"] == "Spain"
f_23 = covid["date"].dt.year == 2023
f_5 = (f_ita | f_ger | f_fra | f_spa)  & f_23
col_utili_5 = ["date", "location", "hosp_patients", "hosp_patients_per_million", "weekly_hosp_admissions", "weekly_hosp_admissions_per_million"]

# %% [markdown]
# ## 5. Riguardo le nazioni di Italia, Germania, Francia e Spagna in tutto il 2023:
# **a.** mostrare la somma dei pazienti ospitalizzati per ognuna <br>
# **b.** se ci sono dati nulli, con un breve commento scrivere se può essere possibile gestirli tramite sostituzione o meno

# %%
igfs = covid.loc[f_5, col_utili_5]

# %% [markdown]
# ## 5. Riguardo le nazioni di Italia, Germania, Francia e Spagna in tutto il 2023:
# **a.** mostrare la somma dei pazienti ospitalizzati per ognuna <br>

# %%
igfs.groupby("location", as_index=False).agg({"hosp_patients": "sum", "hosp_patients_per_million": "sum", "weekly_hosp_admissions":"sum", "weekly_hosp_admissions_per_million":"sum"})
# Out:
#   location  hosp_patients  hosp_patients_per_million  weekly_hosp_admissions  \
# 0   France      1382574.0                   20388.03                268117.0
# 1  Germany            0.0                       0.00                897776.0
# 2    Italy      1175272.0                   19907.25                592019.0
# 3    Spain       354602.0                    7456.05                299463.0
#
#    weekly_hosp_admissions_per_million
# 0                             3953.76
# 1                            10768.60
# 2                            10027.92
# 3                             6296.70

# %% [markdown]
# ## 5. Riguardo le nazioni di Italia, Germania, Francia e Spagna in tutto il 2023:
# **b.** se ci sono dati nulli, con un breve commento scrivere se può essere possibile gestirli tramite sostituzione o meno

# %% [markdown]
# La Germania contiene in entrambe le prime 2 colonne (hosp_patients e hosp_patients_per_milion) dati nulli. <br>
# Quindi il vero e proprio dato richiesto non può essere letto. <br>
# I dati relativi ai ricoveri settimanali (weekly_hosp_admissions) sono popolati e quindi potrebbero comunque essere utili per analisi alternative. <br>
# Considerando le forti differenza tra i diversi paesi nella gestione della sanita ed in particolare della pandemia covid sconsiglio fortemente di sostituire i dati nulli. <br>
# Piuttosto scegliere altri attributi per l'analsi del fenomeno.
